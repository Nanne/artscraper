# %%
## Install the library first
#!pip install https://github.com/sodascience/artscraper.git
from pathlib import Path

from artscraper import GoogleArtScraper, WikiArtScraper, PhiladelphiaMuseumScraper, RijksmuseumScraper

# to show the images
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # 1. Examples in interactive mode
#
# Use this mode to download images one by one, or to create your workflow

# %% [markdown]
# ## 1.1. WikiArt
#
# Make sure to obtain [the API keys](https://www.wikiart.org/en/App/GetApi).

# %%
Path("data").mkdir(exist_ok=True)

art_url = "https://www.wikiart.org/en/aleksandra-ekster/women-s-costume-1918"

scraper = WikiArtScraper()
scraper.load_link(art_url)
metadata = scraper.get_metadata()
scraper.save_image("data/wikiart_example.jpg")
print(metadata)

# display the image
img = mpimg.imread("data/wikiart_example.jpg")
plt.imshow(img)
plt.show()

# make sure to close the scraper
scraper.close()
# Out:
# {'id': '57726ffdedc2cb3880bc65ec', 'title': "Women's costume", 'url': 'women-s-costume-1918', 'artistUrl': 'aleksandra-ekster', 'artistName': 'Ekster Aleksandra', 'artistId': '57726d7aedc2cb3880b478db', 'completitionYear': 1918, 'dictionaries': ['57726b51edc2cb3880ad7548', '57726b4eedc2cb3880ad6e40'], 'location': '', 'period': None, 'serie': None, 'genres': ['design'], 'styles': ['Cubo-Futurism'], 'media': [], 'sizeX': None, 'sizeY': None, 'diameter': None, 'galleries': [], 'tags': ['arts-and-crafts', 'clothing-and-textile', 'designs-and-sketches'], 'description': '', 'width': 343, 'image': 'https://uploads8.wikiart.org/images/aleksandra-ekster/women-s-costume-1918.jpg', 'height': 514, 'link': 'https://www.wikiart.org/en/aleksandra-ekster/women-s-costume-1918'}

# %% [markdown]
# ## 1.2 GoogleArt

# %%
art_url = "https://artsandculture.google.com/asset/helena-hunter-fairytales/dwFMypq0ZSiq6w"

# If you are on Windows, you can download geckodriver, place it in your directory,
#  and use the argument geckodriver_path="geckodriver.exe"
scraper = GoogleArtScraper() 
scraper.load_link(art_url)
metadata = scraper.get_metadata()
scraper.save_image("data/googleart_example.png")
print(metadata)

# display the image
img = mpimg.imread("data/googleart_example.png")
plt.imshow(img)
plt.show()

# make sure to close the scraper
scraper.close()
# Out:
# {'main_text': '', 'title': 'Helena Hunter FAIRYTALES', 'id': 'dwFMypq0ZSiq6w', 'link': 'https://artsandculture.google.com/asset/helena-hunter-fairytales/dwFMypq0ZSiq6w'}

# %% [markdown]
# ## 1.3 Philadelphia Museum

# %%
art_url = "https://philamuseum.org/collection/object/326615"

scraper = RijksmuseumScraper() 
scraper.load_link(art_url)
metadata = scraper.get_metadata()
scraper.save_image("data/philamuseum_example.png")
print(metadata)

# display the image
img = mpimg.imread("data/philamuseum_example.png")
plt.imshow(img)
plt.show()

# make sure to close the scraper
scraper.close()
# Out:
# {'main_text': '', 'title': 'summer afternoon', 'date': '1975-1977', 'artist': 'sidney goodman, (american, 1936–2013)', 'medium': 'oil on canvas', 'dimensions': '6 feet 2 inches × 7 feet 6 inches (188 × 228.6 cm)', 'classification': 'paintings', 'credit line': 'gift of dr. and mrs. stephen silberstein, 2013', 'accession number': '2013-5-1', 'geography': 'made in philadelphia, pennsylvania, united states, north and central america', 'id': '326615', 'link': 'https://philamuseum.org/collection/object/326615'}

# %% [markdown]
# ## 1.4 Rijksmuseum

# %%
art_url = "https://www.rijksmuseum.nl/en/collection/RP-P-2009-2575"

scraper = RijksmuseumScraper() 
scraper.load_link(art_url)
metadata = scraper.get_metadata()
scraper.save_image("data/rijksmuseum_example.png")
print(metadata)

# display the image
img = mpimg.imread("data/rijksmuseum_example.png")
plt.imshow(img)
plt.show()

# make sure to close the scraper
scraper.close()

# %% [markdown]
# # 2. Examples in automatic mode
#
# Use this mode to download many images. Each artwork will be downloaded in its own folder (containing the image and the metadata) within the folder specified in the argument `output_dir`.

# %% [markdown]
# ## 2.1 WikiArt example

# %%
some_links = [
    "https://www.wikiart.org/en/aleksandra-ekster/women-s-costume-1918",
    "https://www.wikiart.org/en/aleksandra-ekster/still-life-1913",
    "https://www.wikiart.org/en/aleksandra-ekster/view-of-paris-1912"
]

with WikiArtScraper(output_dir="data") as scraper:
    for url in some_links:
        scraper.load_link(url)
        scraper.save_metadata()
        scraper.save_image()

# %% [markdown]
# ## 2.2 GoogleArt example

# %%
some_links = [
    "https://artsandculture.google.com/asset/helena-hunter-fairytales/dwFMypq0ZSiq6w",
    "https://artsandculture.google.com/asset/erina-takahashi-and-isaac-hernandez-in-fantastic-beings-laurent-liotardo/MQEhgoWpWJUd_w",
    "https://artsandculture.google.com/asset/rinaldo-roberto-masotti/swG7r2rgfvPOFQ"
]

# If you are on Windows, you can download geckodriver, place it in your directory,
#  and use the argument geckodriver_path="geckodriver.exe"
with GoogleArtScraper("data") as scraper: 
    for url in some_links:
        scraper.load_link(url)
        scraper.save_metadata()
        scraper.save_image()
